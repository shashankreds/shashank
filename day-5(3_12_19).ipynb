# %%
print ("welcome to python programming")
# Out:
# welcome to python programming

# %%
x=2375482374
print(x)
# Out:
# 2375482374

# %% [markdown]
# # python programming
# ## python programming
# ### python programming
#
#
# 1.   python basics
# 2.   python syntax

# %% [markdown]
# 1.   python advanced
# 2.   basic syntax

# %% [markdown]
# ![image](https://images.pexels.com/photos/459225/pexels-photo-459225.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=500)

# %% [markdown]
# [click here](https://sites.google.com/view/gitam-221710405018/about-the-program)
